# %%
from scipy import stats
ortalama=10
dagilim=stats.poisson(ortalama)
p0=dagilim.pmf(k=0)
print(p0*100)
# Out:
# 0.004539992976248485

# %%
ortalama=5
dagilim=stats.poisson(ortalama)
p9=dagilim.pmf(k=9)
print(p9*100)
# Out:
# 3.6265577415643713

# %%
ortalama=6
dagilim=stats.poisson(ortalama)
p3=dagilim.cdf(3)
print(p3)
# Out:
# 0.15120388277664784

# %%
ortalama=2
dagilim=stats.poisson(ortalama)
p3=dagilim.cdf(1)
print(1-p3)
# Out:
# 0.593994150290162
